# %%
# imports
import pandas as pd
from sklearn.metrics import cohen_kappa_score, accuracy_score, precision_score, recall_score, f1_score

# %%
test_df = pd.read_csv('test_w_preds.csv')
test_df
# Out:
#       Unnamed: 0  study_type    patient_id  \
# 0              0  XR_FOREARM  patient11463
# 1              1  XR_FOREARM  patient11463
# 2              2  XR_FOREARM  patient11449
# 3              3  XR_FOREARM  patient11449
# 4              4  XR_FOREARM  patient11408
# ...          ...         ...           ...
# 3192        3192    XR_ELBOW  patient11536
# 3193        3193    XR_ELBOW  patient11402
# 3194        3194    XR_ELBOW  patient11402
# 3195        3195    XR_ELBOW  patient11875
# 3196        3196    XR_ELBOW  patient11875
#
#                                                img_path  label  pred
# 0     MURA-v1.1/valid/XR_FOREARM/patient11463/study1...      0     0
# 1     MURA-v1.1/valid/XR_FOREARM/patient11463/study1...      0     1
# 2     MURA-v1.1/valid/XR_FOREARM/patient11449/study1...      0     0
# 3     MURA-v1.1/valid/XR_FOREARM/patient11449/study1...      0     0
# 4     MURA-v1.1/valid/XR_FOREARM/patient11408/study1...      1     0
# ...

# %%
y_true = test_df['label'].values
y_pred = test_df['pred'].values

# %%
print('Dense Net Evaluation on Test Data')
print(f'Cohen Kappa: {cohen_kappa_score(y_true, y_pred)}')
print(f'Accuracy:    {accuracy_score(y_true, y_pred)}')
print(f'Precision:   {precision_score(y_true, y_pred)}')
print(f'Recall:      {recall_score(y_true, y_pred)}')
print(f'F1-score:    {f1_score(y_true, y_pred)}')
# Out:
# Dense Net
# Cohen Kappa: 0.4368696842982791
# Accuracy:    0.7225523928683141
# Precision:   0.805318138651472
# Recall:      0.5542483660130719
# F1-score:    0.6566008517228029

# %%
test_df = pd.read_csv('test_w_preds_vgg.csv')
test_df

y_true = test_df['label'].values
y_pred = test_df['pred'].values

print('VGG Evaluation on Test Data')
print(f'Cohen Kappa: {cohen_kappa_score(y_true, y_pred)}')
print(f'Accuracy:    {accuracy_score(y_true, y_pred)}')
print(f'Precision:   {precision_score(y_true, y_pred)}')
print(f'Recall:      {recall_score(y_true, y_pred)}')
print(f'F1-score:    {f1_score(y_true, y_pred)}')
# Out:
# VGG Evaluation on Test Data
# Cohen Kappa: 0.3912913194638242
# Accuracy:    0.6990928995933687
# Precision:   0.7414965986394558
# Recall:      0.5699346405228758
# F1-score:    0.6444937176644494
